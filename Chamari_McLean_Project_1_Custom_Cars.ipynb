# %% [markdown]
# <a href="https://colab.research.google.com/github/ceemari/CustomCarsProject/blob/main/Chamari_McLean_Project_1_Custom_Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print a line of equal signs for header
print("==================================================")

# Print a blank space
print("                                                  ")

# Print Welcome to the UMBC Car Customization Form

print("Welcome to the UMBC Car Customization Form")

# Print a blank space
print("                                                  ")

# Print a line of equal signs for close header
print("==================================================")

# Print a blank space
print("                                                   ")

# Print the instructions
print("Please enter the letter of the selection you're looking for.")

# Print a blank space
print("                                                      ")

# Print ~ Make and Model
print("~ Make and Model ~")

# Print a blank space
print("                                                       ")

# Print Question to user
print("1. What model of car are you ordering?")

# Print a blank space
print("                                                       ")

# Print options for user
print("a. Lightning Speedster")
print("b. Eco Leaf")
print("c. Harp Chord")
print("d. Chevron Jolt")

# Print a blank space
print("                                                         ")


# Print the prompt to user
model = input("Please enter the lower case letter here:   ")

# Print a blank space
print("                                                         ")

# List question 2
print("2. Would you like to upgrade from the four door option to the two door option?")
DoorUpgrade = input("Please enter 'yes' or 'no':       ")

# Print a blank space
print("                                                         ")

# Print ~ Exterior ~
print("~ Exterior ~")

# List question 3
print("What color would you like your car to be?")
color = input("You may enter the name of any color you'd like:")

# Print a blank space
print("                                                         ")

# List question 4
print("4. Would you like the deluxe winter package?")
WinterPkg = input("Please enter 'yes' or 'no': ")

# Print Interior header
print("~ Interior ~")

# List question 5
print("Which engine would you like your engine to have?")

# List user choices for question 5
print("a. I-4 Entry Engine")
print("b. V-6 Performance Engine")
print("c. Eco Diesel Engine")
Engine = input("Please enter the lower case letter here:   ")

 # Print blank space
print("                                                                       ")

# List question 6
print("Would you like to heated seats?")
HeatSeat = input("Please enter 'yes' or 'no': ")

# Print blank space
print("                                                                       ")

# Print a line of equal signs
print("=======================================================================")

# Summary
print(f"Model: {model}")
print(f"Four door upgrade: {DoorUpgrade}")
print(f"Winter Package: {WinterPkg}")
print(f"Color chosen: {color}")
print(f"Engine: {Engine}")
print(f"Heated Seats: {HeatSeat}")
# Out:
# ...
#
# Welcome to the UMBC Car Customization Form
#
# ...
#
# Please enter the letter of the selection you're looking for.
#
# ~ Make and Model ~
#
# 1. What model of car are you ordering?
#
# a. Lightning Speedster
# b. Eco Leaf
# c. Harp Chord
# d. Chevron Jolt
#
# Please enter the lower case letter here:   a
#
# 2. Would you like to upgrade from the four door option to the two door option?
# Please enter 'yes' or 'no':       yes
#
# ~ Exterior ~
# What color would you like your car to be?
# You may enter the name of any color you'd like:red
#
# 4. Would you like the deluxe winter package?
# Please enter 'yes' or 'no': no
# ~ Interior ~
# Which engine would you like your engine to have?
# a. I-4 Entry Engine
# b. V-6 Performance Engine
# c. Eco Diesel Engine
# Please enter the lower case letter here:   b
#
# Would you like to heated seats?
# Please enter 'yes' or 'no': no
#
# ...
# Model: a
# Four door upgrade: yes
# Winter Package: no
# Color chosen: red
# Engine: b
# Heated Seats: no
